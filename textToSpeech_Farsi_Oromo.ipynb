# %% [markdown]
# <a href="https://colab.research.google.com/github/kaizengrowth/machine_learning_projects/blob/main/textToSpeech_Farsi_Oromo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ttsmms
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 5.1 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...

# %%
from ttsmms import TTS, download

# %%
dir_path = download("fas","./data") # lang_code, dir for save model
# Out:
# downloading fas from https://dl.fbaipublicfiles.com/mms/tts/fas.tar.gz
# extract all fas to ./data/fas
# Done

# %%
tts=TTS(dir_path)

# %%
wav=tts.synthesis("سلام به فارسی")

# %%
wav
# Out:
# {'x': array([-0.00023702, -0.00026454, -0.0002963 , ...,  0.0001301 ,
#          0.00016558,  0.00015243], dtype=float32),
#  'sampling_rate': 16000}

# %%
import IPython.display as ipd
ipd.Audio(wav["x"], rate=wav["sampling_rate"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
tts.synthesis("환호",wav_path="example.wav")
# Out:
# 'example.wav'
